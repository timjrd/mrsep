# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#   return false;
# }

# %%
# %run ../src/plots.py

# %%
plot_all("../results-004-null-const-filters")
# Out:
# Paths              ../results-004-null-const-filters/clpA/3721cdda46/*/a010-r001
# Datasets           clpA/3721cdda46/ref clpA/3721cdda46/sim
# Alleles database   10
# Alleles in reads   1
# Reads              690
# Bases              59310
# Faulty reads       47.10 %
# Faulty bases       0.76 %
# Timeout            60 minutes
#
# Solver stats (sim):
#   591    filtered_nb_positions
#   690    filtered_nb_read_mappings
#   1      filtered_nb_strain_types
#   690    solver_nb_constraints_1_not_null
#   579    solver_nb_constraints_3_4
#   579    solver_nb_coverages_not_null
#   690    solver_nb_vars
#   591    unfiltered_nb_positions
#   690    unfiltered_nb_read_mappings
#   10     unfiltered_nb_strain_types
#
# Solver stats (ref):
#   591    filtered_nb_positions
#   690    filtered_nb_read_mappings
#   1      filtered_nb_strain_types
#   690    solver_nb_constraints_1_not_null
#   579    solver_nb_constraints_3_4
#   579    solver_nb_coverages_not_null
#   690    solver_nb_vars
# ...

# %%
plot_all("../results-004-null-filter")
# Out:
# Paths              ../results-004-null-filter/clpA/3721cdda46/*/a010-r001
# Datasets           clpA/3721cdda46/ref clpA/3721cdda46/sim
# Alleles database   10
# Alleles in reads   1
# Reads              690
# Bases              59310
# Faulty reads       47.10 %
# Faulty bases       0.76 %
# Timeout            60 minutes
#
# Solver stats (sim):
#   591    filtered_nb_positions
#   690    filtered_nb_read_mappings
#   1      filtered_nb_strain_types
#   690    solver_nb_constraints_1_not_null
#   579    solver_nb_constraints_3_4
#   579    solver_nb_coverages_not_null
#   690    solver_nb_vars
#   591    unfiltered_nb_positions
#   690    unfiltered_nb_read_mappings
#   10     unfiltered_nb_strain_types
#
# Solver stats (ref):
#   591    filtered_nb_positions
#   690    filtered_nb_read_mappings
#   1      filtered_nb_strain_types
#   690    solver_nb_constraints_1_not_null
#   579    solver_nb_constraints_3_4
#   579    solver_nb_coverages_not_null
#   690    solver_nb_vars
# ...
